# %% [markdown]
# # 1-Les Dictionnaires

# %%
Mois = {'Jan': 31, 'Fév' : 28, 'Mars' : 30 }
print(Mois)
# Out:
# {'Jan': 31, 'Fév': 28, 'Mars': 30}

# %%
Mois['Jan']
# Out:
# 31

# %%
Mois['Jan']= 30
print(Mois)
# Out:
# {'Jan': 30, 'Fév': 28, 'Mars': 30}

# %%
Mois['Avril']= 28

# %%
print(Mois)
# Out:
# {'Jan': 30, 'Fév': 28, 'Mars': 30, 'Avril': 28}

# %%
Mois.keys()
# Out:
# dict_keys(['Jan', 'Fév', 'Mars', 'Avril'])

# %%
Mois.values()
# Out:
# dict_values([30, 28, 30, 28])

# %%
Mois.items()
# Out:
# dict_items([('Jan', 30), ('Fév', 28), ('Mars', 30), ('Avril', 28)])
