# %% [markdown]
# # 1-Structure conditionnelle

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 5

# %%
if x > 10 : 
  print(x, "est plus grand que 10")

# %%
a = -10

# %%
if a > 0:
  b=0
  print(b)
else:
  b=-1
  print(b)
# Out:
# -1
