# %% [markdown]
# # 1-Les tuples

# %%
tuple = ()

# %%
Tuple = (0, 1, 2, 'hi')

# %%
print(Tuple)
# Out:
# (0, 1, 2, 'hi')

# %%
Tuple[3]
# Out:
# 'hi'

# %%
a, b = 1, 2

# %%
(a, b) = (1, 2)

# %%
c =(3)

# %%
type(c)
# Out:
# int

# %%
type(Tuple)
# Out:
# tuple
