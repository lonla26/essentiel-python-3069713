# %% [markdown]
# # 1-Les ensembles

# %%
ens = {}

# %%
ens = set()

# %%
Panier = {'orange', 'poire', 'banane', 'mangue'}
print(Panier)
# Out:
# {'poire', 'mangue', 'orange', 'banane'}

# %%
'poire' in Panier
# Out:
# True

# %%
'Poire' in Panier
# Out:
# False

# %%
'poire ' in Panier
# Out:
# False

# %%
Magie = set('abracadabra')
print(Magie)
# Out:
# {'d', 'a', 'c', 'b', 'r'}

# %%
Magie2 = set('alazacam')
print(Magie2)
# Out:
# {'m', 'l', 'a', 'c', 'z'}

# %%
print(Magie & Magie2)
# Out:
# {'a', 'c'}

# %%
print(Magie|Magie2)
# Out:
# {'d', 'm', 'l', 'a', 'c', 'b', 'r', 'z'}
