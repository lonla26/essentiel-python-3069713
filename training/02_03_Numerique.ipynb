# %% [markdown]
# # 1 Les numeriques
# - Les entiers
# - Les flottants
# - Les nombres complexes

# %% [markdown]
# ### 1.1 Les nombres entiers

# %%
a = 25

# %%
a
# Out:
# 25

# %%
b= -65789911

# %%
b
# Out:
# -65789911

# %%
a + b
# Out:
# -65789886

# %% [markdown]
# ### 1.2 Les nombres flottants

# %%
a = 2.23

# %%
a
# Out:
# 2.23

# %%
b = -2.25e14
b
# Out:
# -225000000000000.0

# %% [markdown]
# ### 1.3 Les nombres complexes

# %%
a = 2 + 3j
a
# Out:
# (2+3j)

# %%
type(a)
# Out:
# complex
