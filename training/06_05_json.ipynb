# %% [markdown]
# # 1 - JSON

# %%
import json

# %%
with open('data/movies.json') as monfichier:
    dataset = json.load(monfichier)

# %%
dataset
# Out:
# {'abstract': 'Hello how are you today ?',
#  'link_01': {'name': 'Welcome page', 'priority': '1'},
#  'link_02': {'name': 'Home page', 'priority': '2'}}
