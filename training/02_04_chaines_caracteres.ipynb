# %% [markdown]
# # 1 - Les chaînes de caractères

# %%
a = 'Hello'
a
# Out:
# 'Hello'

# %%
a = "Hello"
a
# Out:
# 'Hello'

# %%
print(a)
# Out:
# Hello

# %%
type(a)
# Out:
# str

# %%
a[1]
# Out:
# 'e'

# %%
a[0]
# Out:
# 'H'

# %%
a[1:3]
# Out:
# 'el'

# %%
a.upper()
# Out:
# 'HELLO'

# %%
a.lower()
# Out:
# 'hello'

# %%
a
# Out:
# 'Hello'

# %%
a = a.lower()
a
# Out:
# 'hello'

# %%
len(a)
# Out:
# 5
