# %%
2+2
# Out:
# 4

# %%
8-2
# Out:
# 6

# %%
6*7
# Out:
# 42

# %%
2**2
# Out:
# 4

# %%
5**2 #puissance
# Out:
# 25

# %%
7/2 #division decimale
# Out:
# 3.5

# %%
7//3 #quotient de la division euclidienne
# Out:
# 2

# %%
7%3 #reste de la division euclidienne
# Out:
# 1
