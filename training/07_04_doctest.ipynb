# %% [markdown]
# # 1 - Doctest

# %%
import doctest

# %%
doctest.testfile(r"test/example.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 doctest.testfile(r"test/example.txt")
#
# File /usr/local/python/3.12.1/lib/python3.12/doctest.py:2095, in testfile(filename, module_relative, name, package, globs, verbose, report, optionflags, extraglobs, raise_on_error, parser, encoding)
#    2091     raise ValueError("Package may only be specified for module-"
#    2092                      "relative paths.")
#    2094 # Relativize the path
# -> 2095 text, filename = _load_testfile(filename, package, module_relative,
#    2096                                 encoding or "utf-8")
#    2098 # If no name was given, then use the file's name.
#    2099 if name is None:
#
# File /usr/local/python/3.12.1/lib/python3.12/doctest.py:239, in _load_testfile(filename, package, module_relative, encoding)
# ...
