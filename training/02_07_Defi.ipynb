# %% [markdown]
# # 1- Defi

# %% [markdown]
# 1. Créer une variable où vous stockerez la valeur numérique de votre choix.
# 2. Convertir cette variable en string.
# 3. Afficher ensuite les éléments suivants :
#  le nombre choisi est : (affichage de la valeur contenue dans votre variable)

# %%
# 1ère étape
ma_variable = 26
ma_variable
# Out:
# 26

# %%
# 2ème étape
ma_variable_str = str(ma_variable)

# %%
ma_variable_str
# Out:
# '26'

# %%
type(ma_variable_str)
# Out:
# str

# %%
# 3ème étape
print("le nombre choisi est : " + ma_variable_str)
# Out:
# le nombre choisi est : 26
