# %% [markdown]
# # 1 - Les packages

# %%
from Operation import *

# %%
from Operation.Division import DivisionPar2

# %%
age = 20

# %%
print("L'age divisé par deux est:", DivisionPar2(age))
# Out:
# L'age divisé par deux est: 10.0

# %% [markdown]
# Exemples de packages : "beautifulsoup" permet de faire du scrapping web (fichiers HTML ou XML), Pandas, etc...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
