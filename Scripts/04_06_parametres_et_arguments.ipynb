# %% [markdown]
# # 1 Paramètres et Arguments

# %%
def bonjour(prenom):
  print('bonjour' + ' ' +prenom)

# %%
bonjour('Alison')
# Out:
# bonjour Alison

# %%
bonjour('Damien')
# Out:
# bonjour Damien

# %%
def somme(*args):
  x=0
  for i in args:
    x+=i
  print("Ma somme totale :", x)

# %%
somme(1,2,3)
# Out:
# Ma somme totale : 6
