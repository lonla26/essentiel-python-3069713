# %% [markdown]
# ## 1 Les listes

# %% [markdown]
# les listes sont écrites entre crochets

# %%
liste = []

# %%
listeA = [0,2,3,'hi']
listeA
# Out:
# [0, 2, 3, 'hi']

# %%
listeB = [0,1,2,3]
listeB
# Out:
# [0, 1, 2, 3]

# %%
listeC = [0,1,2, 'hi', [0,1]]
listeC
# Out:
# [0, 1, 2, 'hi', [0, 1]]

# %%
listeC[1]
# Out:
# 1

# %%
listeC[0:2:6]
# Out:
# [0]

# %%
Liste = [2,0,1,6]
Liste
# Out:
# [2, 0, 1, 6]

# %%
Liste.sort()
print(Liste)
# Out:
# [0, 1, 2, 6]

# %%
Liste.append(['hi', 'hello'])
print(Liste)
# Out:
# [0, 1, 2, 6, ['hi', 'hello']]

# %%
Liste = [2,0,1,6]
Liste
# Out:
# [2, 0, 1, 6]

# %%
Liste.extend(['hi', 'hello'])
print(Liste)
# Out:
# [2, 0, 1, 6, 'hi', 'hello']

# %%
Liste.count(0)
# Out:
# 1
