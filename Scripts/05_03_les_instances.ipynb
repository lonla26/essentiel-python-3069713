# %% [markdown]
# # 1 les instances

# %%
class MaClasse:
  "un exemple de classe"
  variable = 1
  def somme(self, a, b):
    return a+b

# %%
MonObjet = MaClasse()

# %%
MonObjet

# %%
MonObjet.variable
# Out:
# 1
