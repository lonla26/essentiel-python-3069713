# %% [markdown]
# # 1 Les fonctions

# %%
def donne_age():
  return 32

# %%
donne_age()
# Out:
# 32

# %%
def age_plus2(a):
  return a+2

# %%
age_plus2(10)
# Out:
# 12

# %%
age_plus2(45)
# Out:
# 47
