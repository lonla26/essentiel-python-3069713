# %% [markdown]
# ## 1 Les ensembles

# %% [markdown]
# les ensembles sont écrits entre accolades

# %%
ens = {}

# %%
ens = set()

# %%
Panier = {'orange', 'poire', 'banane', 'mangue'}
print(Panier) #l'affichage ne tient pas compte de l'ordre
# Out:
# {'banane', 'mangue', 'poire', 'orange'}

# %%
'poire' in Panier
# Out:
# True

# %%
'Poire' in Panier
# Out:
# False

# %%
Magie = set('abracadabra')

# %%
print(Magie)
# Out:
# {'c', 'd', 'b', 'a', 'r'}

# %%
Magie2 = set('alacazam')

# %%
print(Magie2)
# Out:
# {'c', 'z', 'a', 'l', 'm'}

# %%
print(Magie & Magie2)
# Out:
# {'c', 'a'}
