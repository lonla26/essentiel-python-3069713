# %% [markdown]
# ## 1 Les opérateurs

# %%
a = 5

# %%
a += 5

# %%
a
# Out:
# 10

# %%
b = 15 
b
# Out:
# 15

# %%
a
# Out:
# 10

# %%
a > b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a < 15 and a < 20
# Out:
# True

# %%
a < 5 or a < 20
# Out:
# True

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
b = 10

# %%
a is b
# Out:
# True
