# %% [markdown]
# ## 1- Les tuples

# %% [markdown]
# les tuples sont écrits entre parenthèses

# %%
tuple = ()

# %%
Tuple = (0, 1, 2, 'hi')

# %%
print(Tuple)
# Out:
# (0, 1, 2, 'hi')

# %%
Tuple[2]
# Out:
# 2

# %%
a, b = 1, 2

# %%
(a,b) = (1,2)

# %%
c =(3)

# %%
type(c)
# Out:
# int

# %%
type(Tuple)
# Out:
# tuple
