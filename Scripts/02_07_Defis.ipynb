# %% [markdown]
# ## 1 Defi

# %% [markdown]
# 1. Créer une variable où vous stockerez la valeur de votre choix.
# 2. Convertir cette variable en string.
# 3. Afficher ensuite les éléments suivants :
# le nombre choisi est : (affichage de la valeur contenues dans votre variable)

# %%
# 1ere etape
ma_variable = 26

# %%
ma_variable
# Out:
# 26

# %%
#2eme etape
mystring = str(ma_variable)
mystring
# Out:
# '26'

# %%
#3eme etape
print("le nombre choisi est : " + mystring)
# Out:
# le nombre choisi est : 26
