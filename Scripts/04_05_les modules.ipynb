# %% [markdown]
# # 1 Les modules

# %%
import testModule

# %%
testModule.DireBonjour()
# Out:
# Bonjour

# %%
print(testModule.DivisionPar2(10))
# Out:
# 5.0

# %%
from testModule import DireBonjour

# %%
DireBonjour()
# Out:
# Bonjour
