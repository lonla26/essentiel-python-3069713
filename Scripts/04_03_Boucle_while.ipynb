# %% [markdown]
# # 1 Boucle While

# %% [markdown]
# while condition:
#
#     instruction A

# %%
x = 1

# %%
while x<4:
  print("x a pour valeur",x)
  x*=2
  print(x)
# Out:
# x a pour valeur 1
# 2
# x a pour valeur 2
# 4
